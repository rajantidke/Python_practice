# %%
pip install jupyterthemes
# Out:
# ...
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ------- -------------------------------- 1.3/7.0 MB 7.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.9/7.0 MB 10.5 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 13.4 MB/s  0:00:00
# ...
#
#    ------------- -------------------------- 3/9 [lesscpy]
#    ----------------- ---------------------- 4/9 [lark]
#    ----------------------------------- ---- 8/9 [jupyterthemes]
#    ---------------------------------------- 9/9 [jupyterthemes]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !jt -l
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
# !jt -t gruvboxl
