# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
len?
# Out:
# Signature: len(obj, /)
# Docstring: Return the number of items in a container.
# Type:      builtin_function_or_method

# %%
L = [1,2,3]

# %%
L.insert?
# Out:
# Signature: L.insert(index, object, /)
# Docstring: Insert object before index.
# Type:      builtin_function_or_method

# %%
L?
# Out:
# Type:        list
# String form: [1, 2, 3]
# Length:      3
# Docstring:
# Built-in mutable sequence.
#
# If no argument is given, the constructor creates a new empty list.
# The argument must be an iterable if specified.

# %%
def square(a):
    """Returns a square of given number a"""
    return a ** 2

# %%
square?
# Out:
# Signature: square(a)
# Docstring: Returns a square of given number a
# File:      c:\users\rajan\appdata\local\temp\ipykernel_33676\1745371759.py
# Type:      function

# %%
len??
# Out:
# Signature: len(obj, /)
# Docstring: Return the number of items in a container.
# Type:      builtin_function_or_method

# %%
square??
# Out:
# Signature: square(a)
# Source:
# def square(a):
#     """Returns a square of given number a"""
#     return a ** 2
# File:      c:\users\rajan\appdata\local\temp\ipykernel_33676\1745371759.py
# Type:      function

# %%
dir(L)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
# Tab completion is also useful when importing objects from packages. 
# Here we’ll use it to find all possible imports in the itertools package that start with co:
from itertools import co

# %%
import

# %%
*warning?

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 1482-07C2
#
#  Directory of C:\Users\rajan\Personal - ASUS\Python_Data_Science_handbook
#
# 05/24/2026  03:34    <DIR>          .
# 05/19/2026  01:28    <DIR>          ..
# 05/24/2026  03:34    <DIR>          .ipynb_checkpoints
# 05/24/2026  03:06                 0 conda activate python_ds_handbook
# 05/24/2026  03:34               143 myscript.py
# 05/24/2026  03:34             8,498 Untitled.ipynb
#                3 File(s)          8,641 bytes
#                3 Dir(s)  414,691,946,496 bytes free

# %%
# !python myscript.py
# Out:
# 1 squared is 1
# 2 squared is 4
# 3 squared is 9

# %%
# %run myscript.py
# Out:
# 1 squared is 1
# 2 squared is 4
# 3 squared is 9

# %%
#any functions defined within it are available for use in your IPython session for the %run, not !python

# %%
square(4)
# Out:
# 16

# %%
#useful magic function is %timeit, which will 
#automatically determine the execution time of the single-line Python statement that follows it
# %timeit L = [n**2 for n in range(1000) ]
# Out:
# 43.2 μs ± 3.01 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
